# %%
overlayed.shape, data.shape
# Out:
# ((512, 896, 3), (512, 896, 3))

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

# data = np.load('data.npy')
frame = np.load('frame.npy')
resized = np.load('resized.npy')
overlayed = np.load('overlayed.npy')

# newsize = frame.shape[:2][1],frame.shape[:2][0]
# resized = cv2.resize(frame, newsize)
# resized = cv2.resize(data, newsize)

# img_combined = cv2.addWeighted(resized, 0.8, mask, 0.8, 0)
img_combined = cv2.addWeighted(frame, 0.8, resized, 0.8, 0)

fig, ax = plt.subplots(2, 2, figsize=(12,10))
fig.suptitle('Horizontally stacked subplots')
ax[0,0].set_title('mask')
ax[0,0].imshow(resized)
ax[0,1].set_title('frame')
ax[0,1].imshow(frame)
ax[1,0].set_title('overlayed')
ax[1,0].imshow(overlayed)
ax[1,1].set_title('img_combined')
ax[1,1].imshow(img_combined)
